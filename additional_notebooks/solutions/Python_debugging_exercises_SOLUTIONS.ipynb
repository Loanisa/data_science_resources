# %% [markdown]
# Find the error(s) in the following code (if any) and rewrite it.

# %%
a, b = 0
if (a = b)
  a + b = c
  print(z)
# Out:
#   File "<ipython-input-1-574e028709c1>", line 2
#     if (a = b)
#         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
a = b = 0
if (a == b):
  c = a + b
  print(c)
# Out:
# 0

# %% [markdown]
# Rewrite the following code in python after removing all syntax error(s).

# %%
250	=	number
WHILE	number<=1000:
  if	number=>750
    print	(number)
    number=number+100
	else
    print(number*2)
    number=number+50
# Out:
#   File "<ipython-input-2-b79a5cd50f29>", line 1
#     250	=	Number
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
number=250
while	number<=1000:
  if	number>=750:
    print(number)
    number=number+100
  else:
    print(number*2)
    number=number+50
# Out:
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 750
# 850
# 950

# %% [markdown]
# Rewrite it after removing all syntactical errors.

# %%
a = int(input("Value:"))
b = 0
for c in range(1,a,2)
  b+=c if c%2==0:
    print(c*3) Else:

    print(c*2) print(b)
# Out:
#   File "<ipython-input-7-8a18c83800a7>", line 3
#     for c in range(1,a,2)
#                          ^
# SyntaxError: expected ':'

# %%
a = int(input("Value:"))
b = 0
for c in range(1,a,2):
  b+=c
  if c%2==0:
    print(c*3)
  else:
    print(c*2)
  print(b)
# Out:
# Value:4
# 2
# 1
# 6
# 4

# %% [markdown]
# *   : is requried at the end of for statement
# *   Indendation is required in all statement after for
# *   == is used for comparison
# *   else is a keyword used in small letters
# *   Print(b) should be outside of the loop

# %% [markdown]
# Rewrite it after removing all syntactical errors.

# %%
HELLO"=string
for I in range(0,len(string)-1)
if string[I]=>"M":
  print(string(I), "*"
else:
  print(string[I-1])

# %%
string="HELLO"
for I in range(0,len(string)-1):
  if string[I]>="M":
    print(string[I], "*")
  else:
    print(string[I-1])
# Out:
# O
# H
# E
# L
